# %% [markdown]
# # Parameters to tune for $\alpha$
#
# - $\alpha_{max}$
# - $\alpha_{min}$

# %%
from albedo_util import modify_attr,read_plot

# %%
import supy
supy.show_version()
# Out:
# supy: 2019.11.24
# supy_driver: 2019a18

# %% [markdown]
# # DecTr

# %% [markdown]
# ## MMS-2017 Tuning

# %%
name='US-MMS'
years=[2017]
read_plot(years,name)

# %% [markdown]
# ### To Test

# %%
name='US-MMS'
years=[2010,2012,2016]
read_plot(years,name)

# %% [markdown]
# ## UMB-2008 Tuning

# %%
name='US-UMB'
years=[2008]
read_plot(years,name)

# %% [markdown]
# ### To test

# %%
name='US-UMB'
years=[2010,2014,2016]
read_plot(years,name)

# %% [markdown]
# ## Oho-2010 Tuning

# %%
name='US-Oho'
years=[2010]
read_plot(years,name)

# %% [markdown]
# ### To Test

# %%
name='US-Oho'
years=[2011,2012,2013]
read_plot(years,name)

# %% [markdown]
# # EveTr

# %% [markdown]
# ## US-Blk-2005 Tuning

# %%
name='US-Blk'
years=[2005]
read_plot(years,name)

# %% [markdown]
# ### To test

# %%
name='US-Blk'
years=[2004,2006,2008]
read_plot(years,name)

# %% [markdown]
# ## CA-Obs-2008 Tuning

# %%
name='CA-Obs'
years=[2008]
read_plot(years,name)

# %% [markdown]
# ### To test

# %%
name='CA-Obs'
years=[2003,2005,2006]
read_plot(years,name)

# %% [markdown]
# ## CA-Qcu-2010 Tuning

# %%
name='CA-Qcu'
years=[2010]
read_plot(years,name)

# %% [markdown]
# ### To test

# %%
name='CA-Qcu'
years=[2005,2008,2009]
read_plot(years,name)

# %% [markdown]
# # Grass

# %% [markdown]
# ## US-AR1-2012 Tuning

# %%
name='US-AR1'
years=[2012]
read_plot(years,name,multiple_run=1)

# %% [markdown]
# ### To test

# %%
name='US-AR1'
years=[2010,2011]
read_plot(years,name,multiple_run=1)

# %% [markdown]
# ## US-KUT-2008 Tuning

# %%
name='US-KUT'
years=[2008]
read_plot(years,name)

# %% [markdown]
# ### To test

# %%
name='US-KUT'
years=[2006,2007]
read_plot(years,name)

# %% [markdown]
# ## US-Skr

# %%
name='US-Skr'
years=[2004]
read_plot(years,name,topyl=0.16)

# %%
name='US-Skr'
years=[2008,2010]
read_plot(years,name,botyl=0.09,topyl=0.16)

# %% [markdown]
# ## US-Mpj

# %%
name='US-Mpj'
years=[2010]
read_plot(years,name)

# %%
name='US-Mpj'
years=[2011,2012]
read_plot(years,name)

# %% [markdown]
# ## US-Dk3

# %%
name='US-Dk3'
years=[2005]
read_plot(years,name)

# %%
name='US-Dk3'
years=[2006,2007]
read_plot(years,name)

# %% [markdown]
# ## BR-Sa3

# %%
name='BR-Sa3'
years=[2003]
read_plot(years,name)

# %%
name='BR-Sa3'
years=[2002]
read_plot(years,name)

# %% [markdown]
# ## US-Aud

# %%
name='US-Aud'
years=[2005]
read_plot(years,name)

# %%
name='US-Aud'
years=[2006,2007]
read_plot(years,name)

# %% [markdown]
# ## US-Wkg

# %%
name='US-Wkg'
years=[2009]
read_plot(years,name)

# %%
name='US-Wkg'
years=[2010,2011]
read_plot(years,name)
