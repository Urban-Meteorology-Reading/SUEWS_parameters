# %% [markdown]
# # Parameters to tune for LAI
#
# - `BaseT`
# - `BaseTe`
# - `LAIMAX`
# - `LAIMin`

# %%
from LAI_util import LAI_tune,LAI_test,sample_plot

# %% [markdown]
# # DecTr

# %% [markdown]
# ## MMS-2017 Tuning

# %%
name='US-MMS'
year=2017
LAI_tune(year,name)

# %% [markdown]
# ### To Test

# %%
name='US-MMS'
years=[2010,2012,2016]
LAI_test(years,name)

# %% [markdown]
# ## UMB-2008 Tuning

# %%
name='US-UMB'
year=2008
LAI_tune(year,name)

# %% [markdown]
# ### To test

# %%
name='US-UMB'
years=[2010,2014,2016]
LAI_test(years,name)

# %% [markdown]
# ## Oho-2010 Tuning

# %%
name='US-Oho'
year=2010
LAI_tune(year,name)

# %% [markdown]
# ### To Test

# %%
name='US-Oho'
years=[2011,2012,2013]
LAI_test(years,name)

# %% [markdown]
# ## Sample Plot

# %%
name = 'US-MMS'
years = [2017]
sample_plot(name, years)

# %% [markdown]
# # EveTr

# %% [markdown]
# ## US-Blk-2005 Tuning

# %%
name = 'US-Blk'
year = 2005
LAI_tune(year, name)

# %% [markdown]
# ### To test

# %%
name = 'US-Blk'
years = [2004, 2006, 2008]
LAI_test(years, name)

# %% [markdown]
# ## CA-Obs-2008 Tuning

# %%
name = 'CA-Obs'
year = 2008
LAI_tune(year, name)

# %% [markdown]
# ### To test

# %%
name = 'CA-Obs'
years = [2003, 2005, 2006]
LAI_test(years, name)

# %% [markdown]
# ## CA-Qcu-2010 Tuning

# %%
name = 'CA-Qcu'
year = 2010
LAI_tune(year, name)

# %% [markdown]
# ### To test

# %%
name = 'CA-Qcu'
years = [2005, 2008, 2009]
LAI_test(years, name)

# %% [markdown]
# # Grass

# %% [markdown]
# ## US-AR1-2012 Tuning

# %%
name = 'US-AR1'
year = 2012
LAI_tune(year, name)

# %% [markdown]
# ### To test

# %%
name = 'US-AR1'
years = [2010, 2011]
LAI_test(years, name)

# %% [markdown]
# ## US-KUT-2008 Tuning

# %%
name = 'US-KUT'
year = 2008
LAI_tune(year, name)

# %% [markdown]
# ### To test

# %%
name = 'US-KUT'
years = [2006, 2007]
LAI_test(years, name)

# %%
name='US-Slt'
year=2012
LAI_tune(year, name)
